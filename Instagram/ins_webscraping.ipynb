# %% [markdown]
# ## Sample Here is aijamayrock from the source website https://www.betterinternetinitiative.org/2023

# %%
import pandas as pd
from apify_client import ApifyClient

# Initialize the ApifyClient with your API token
client = ApifyClient("apify_api_0RMlhCC3PcIjYvp8g3Ga47hdjRVsKf3cSQNB")

# Prepare the Actor input
run_input = {
    "directUrls": [
        "https://www.instagram.com/p/CpNvdBKOrIO/?img_index=1",
    ],
    "resultsLimit": 24,
}

# Run the Actor and wait for it to finish
run = client.actor("apify/instagram-comment-scraper").call(run_input=run_input)

# %% [markdown]
# ### Here I scrape all the comments and save to an excel file

# %%
# Fetch and print Actor results from the run's dataset (if there are any)
Comments_ins = []
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    print(item)
    Comment_ins = item['text']
    print(Comment_ins)
    Comments_ins.append(Comment_ins)
print(Comments_ins)
df2 = pd.DataFrame(Comments_ins, columns=['Comments'])
df2.to_excel('ins_comments.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\0 Hallie Jin\0 Hallie\0 QMSS\0 RA\Media Lab\RA_Media-Lab_Columbia\Instagram\ins_webscraping.ipynb 单元格 4 line 3
#       <a href='vscode-notebook-cell:/d%3A/0%20Hallie%20Jin/0%20Hallie/0%20QMSS/0%20RA/Media%20Lab/RA_Media-Lab_Columbia/Instagram/ins_webscraping.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # Fetch and print Actor results from the run's dataset (if there are any)
#       <a href='vscode-notebook-cell:/d%3A/0%20Hallie%20Jin/0%20Hallie/0%20QMSS/0%20RA/Media%20Lab/RA_Media-Lab_Columbia/Instagram/ins_webscraping.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> Comments_ins = []
# ----> <a href='vscode-notebook-cell:/d%3A/0%20Hallie%20Jin/0%20Hallie/0%20QMSS/0%20RA/Media%20Lab/RA_Media-Lab_Columbia/Instagram/ins_webscraping.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> for item in client.dataset(run["defaultDatasetId"]).iterate_items():
# ...

# %% [markdown]
# ## Get every element from posts in case needs

# %%
from apify_client import ApifyClient

# Initialize the ApifyClient with your API token
client = ApifyClient("apify_api_0RMlhCC3PcIjYvp8g3Ga47hdjRVsKf3cSQNB")

# Prepare the Actor input
run_input = {
    "username": ["aijamayrock"],
    "resultsLimit": 30,
}

# Run the Actor and wait for it to finish
run = client.actor("apify/instagram-post-scraper").call(run_input=run_input)

# Fetch and print Actor results from the run's dataset (if there are any)
likesCounts = []
for item in client.dataset(run["defaultDatasetId"]).iterate_items():
    print(item)
# Out:
# {'id': '3048301225095901710', 'type': 'Sidecar', 'shortCode': 'CpNvdBKOrIO', 'caption': 'Life update: Last month, I officially started my MBA at @columbia_biz. \n\nI know it’s probably a bit surprising. Let me take you back a year. January 2022, I decided that I wanted to get my MBA and apply to Columbia. They have a 16 month expedited program that I had set my sight on.\n\nI have always approached my career and being a creative from a business perspective. I have always really loved that side of my work as well. I have dreams and goals for my career (which I’ll share more of at some point) and some of which rely on more of a business background.\n\nSo January 2022, I bought a GMAT prep course and began studying. No one in my life knew I was thinking of applying. For those of you that know me, I have always struggled in math. I studied for about 5 hours a day for months to finally take the exam. I applied in August, got accepted in October, and had my first day of school on January 9
# ...
